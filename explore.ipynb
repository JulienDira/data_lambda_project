# %%
import os
import pandas as pd
import pyarrow.dataset as ds

# Chemin racine du dossier
table_path = "C:/Users/julie/Documents/Streaming/data_lake/TRANSACTIONS_PENDING"

# Charger récursivement tous les fichiers parquet en tenant compte des partitions
dataset = ds.dataset(table_path, format="parquet", partitioning="hive")

# Convertir en DataFrame pandas
df = dataset.to_table().to_pandas()

# Afficher un aperçu des données
print("Aperçu des données :")
print(df.head())

# Infos sur les colonnes et types
print("\nInformations DataFrame :")
print(df.info())

# Statistiques descriptives des colonnes numériques
print("\nStatistiques descriptives :")
print(df.describe())

# Compter les valeurs manquantes par colonne
print("\nValeurs manquantes par colonne :")
print(df.isna().sum())
# Out:
# Aperçu des données :
#   TRANSACTION_ID                    TIMESTAMP  \
# 0   TXN-4aeb6c15  2025-04-19T07:20:12.305600Z
# 1   TXN-cdf1eb54  2025-04-17T08:57:51.305600Z
# 2   TXN-05db4e32  2025-04-14T00:25:23.305600Z
# 3   TXN-3b1bb2d2  2025-05-08T11:38:25.312495Z
# 4   TXN-c9f2d7da  2025-04-27T03:14:24.305600Z
#
#                      USER_ID_HASHED                  USER_NAME_HASHED  \
# 0  54f57e09864b54ed59a5cc633673dde4  194cd2f711cebc782ada13e259bf61dd
# 1  3ff77438146870ee5dcd120f13dec323  01c3012a4b4c3a3ed2aeefefafa38cc5
# 2  385f7d23d00928a441e647da673b2c06  88700f697fe98f2bf0370a7114d5bacf
# 3  7271fbbbc55316d6aab210f25eeda95c  5447aa4026288039fccf95cf270282b3
# 4  2b4f14972a7ae2a887a3bdaade7bf126  262031397020fd8df478ec13b4b096c5
#
#   PRODUCT_ID  AMOUNT CURRENCY TRANSACTION_TYPE   STATUS            CITY  ...  \
# 0   PROD-669  873.04      JPY          payment  pending        Salvador  ...
# 1   PROD-506  416.12      EUR           refund  pending       São Paulo  ...
# 2   PROD-933  469.41      CAD           refund  pending       Frankfurt  ...
# 3   PROD-609  776.81      GBP          payment  pending         Houston  ...
# 4   PROD-711  970.32      GBP       withdrawal  pending  Rio de Janeiro  ...
#
#          MASKED_IP CUSTOMER_RATING DISCOUNT_CODE  TAX_AMOUNT THREAD  \
# 0  67.112.9xxx.xxx             NaN          None         0.0      2
# 1  102.103.xxx.xxx             NaN          None         0.0      1
# 2  130.68.4xxx.xxx             NaN          None         0.0      2
# 3  239.133.xxx.xxx             NaN          None         0.0      3
# 4  94.167.1xxx.xxx             NaN  DISCOUNT-327         0.0      2
#
#   MESSAGE_NUMBER TIMESTAMP_OF_RECEPTION_LOG  AMOUNT_USD  \
# 0              0        11/05/2025 12:32:55     6.11128
# 1              1        11/05/2025 12:32:55   449.40960
# 2              2        11/05/2025 12:32:55   352.05750
# 3              3        11/05/2025 12:32:55   963.24440
# 4              3        11/05/2025 12:32:55  1203.19680
#
#            ingestion_time ingestion_date
# 0 2025-05-11 12:45:35.844     2025-05-11
# 1 2025-05-11 12:45:35.844     2025-05-11
# 2 2025-05-11 12:45:35.844     2025-05-11
# 3 2025-05-11 12:45:35.844     2025-05-11
# 4 2025-05-11 12:45:35.844     2025-05-11
#
# [5 rows x 30 columns]
#
# Informations DataFrame :
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 30 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   TRANSACTION_ID              9 non-null      object
#  1   TIMESTAMP                   9 non-null      object
#  2   USER_ID_HASHED              9 non-null      object
#  3   USER_NAME_HASHED            9 non-null      object
#  4   PRODUCT_ID                  9 non-null      object
#  5   AMOUNT                      9 non-null      float64
#  6   CURRENCY                    9 non-null      object
#  7   TRANSACTION_TYPE            9 non-null      object
#  8   STATUS                      9 non-null      object
#  9   CITY                        9 non-null      object
#  10  COUNTRY                     9 non-null      object
#  11  PAYMENT_METHOD              9 non-null      object
#  12  PRODUCT_CATEGORY            9 non-null      object
#  13  QUANTITY                    9 non-null      int32
#  14  SHIPPING_STREET             9 non-null      object
#  15  SHIPPING_ZIP                9 non-null      object
#  16  SHIPPING_CITY               9 non-null      object
#  17  SHIPPING_COUNTRY            9 non-null      object
#  18  DEVICE_OS                   9 non-null      object
#  19  DEVICE_BROWSER              9 non-null      object
#  20  MASKED_IP                   9 non-null      object
#  21  CUSTOMER_RATING             1 non-null      float64
#  22  DISCOUNT_CODE               4 non-null      object
#  23  TAX_AMOUNT                  9 non-null      float64
#  24  THREAD                      9 non-null      int32
#  25  MESSAGE_NUMBER              9 non-null      int32
#  26  TIMESTAMP_OF_RECEPTION_LOG  9 non-null      object
#  27  AMOUNT_USD                  9 non-null      float64
#  28  ingestion_time              9 non-null      datetime64[ns]
#  29  ingestion_date              9 non-null      object
# dtypes: datetime64[ns](1), float64(4), int32(3), object(22)
# memory usage: 2.1+ KB
# None
#
# Statistiques descriptives :
#            AMOUNT  QUANTITY  CUSTOMER_RATING  TAX_AMOUNT    THREAD  \
# count    9.000000  9.000000              1.0         9.0  9.000000
# mean   668.131111  7.666667              3.0         0.0  2.333333
# min    281.520000  3.000000              3.0         0.0  0.000000
# 25%    469.410000  8.000000              3.0         0.0  2.000000
# 50%    719.110000  8.000000              3.0         0.0  2.000000
# 75%    796.470000  9.000000              3.0         0.0  3.000000
# max    970.320000  9.000000              3.0         0.0  4.000000
# std    228.702699  1.870829              NaN         0.0  1.322876
#
#        MESSAGE_NUMBER   AMOUNT_USD              ingestion_time
# count        9.000000     9.000000                           9
# mean         4.111111   516.929738  2025-05-11 12:45:35.844000
# min          0.000000     4.972660  2025-05-11 12:45:35.844000
# 25%          2.000000   211.140000  2025-05-11 12:45:35.844000
# 50%          3.000000   449.409600  2025-05-11 12:45:35.844000
# 75%          6.000000   963.244400  2025-05-11 12:45:35.844000
# max          9.000000  1203.196800  2025-05-11 12:45:35.844000
# std          3.100179   439.002661                         NaN
#
# Valeurs manquantes par colonne :
# TRANSACTION_ID                0
# TIMESTAMP                     0
# USER_ID_HASHED                0
# USER_NAME_HASHED              0
# PRODUCT_ID                    0
# AMOUNT                        0
# CURRENCY                      0
# TRANSACTION_TYPE              0
# STATUS                        0
# CITY                          0
# COUNTRY                       0
# PAYMENT_METHOD                0
# PRODUCT_CATEGORY              0
# QUANTITY                      0
# SHIPPING_STREET               0
# SHIPPING_ZIP                  0
# SHIPPING_CITY                 0
# SHIPPING_COUNTRY              0
# DEVICE_OS                     0
# DEVICE_BROWSER                0
# MASKED_IP                     0
# CUSTOMER_RATING               8
# DISCOUNT_CODE                 5
# TAX_AMOUNT                    0
# THREAD                        0
# MESSAGE_NUMBER                0
# TIMESTAMP_OF_RECEPTION_LOG    0
# AMOUNT_USD                    0
# ingestion_time                0
# ingestion_date                0
# dtype: int64

# %%
import pyarrow.dataset as ds
import pandas as pd
import numpy as np
import json

# Charger le dataset
table_path = "C:/Users/julie/Documents/Streaming/data_lake/TRANSACTIONS_PENDING"
dataset = ds.dataset(table_path, format="parquet", partitioning="hive")
df = dataset.to_table().to_pandas()

# Colonnes d'exemple
columns = ["TRANSACTION_ID", "AMOUNT", "STATUS"]
df_proj = df

# Pagination : page 1, 10 lignes
page_size = 10
page = 1
start = (page - 1) * page_size
end = start + page_size
page_df = df_proj.iloc[start:end]

# Fonction nettoyage complète
def clean_df_for_json(df: pd.DataFrame) -> pd.DataFrame:
    # Remplacer inf et -inf par NaN
    df.replace([np.inf, -np.inf], np.nan, inplace=True)

    # Convertir datetime en string ISO 8601 (en remplaçant NaT par None)
    for col in df.select_dtypes(include=['datetime64[ns, UTC]', 'datetime64[ns]']):
        df[col] = df[col].astype(str).replace('NaT', None)

    # Forcer le type object pour pouvoir mettre None
    df = df.astype(object)

    # Remplacer NaN par None
    df = df.where(pd.notnull(df), None)

    return df

page_df_clean = clean_df_for_json(page_df)

print(page_df_clean)

# Essayer de convertir en JSON
try:
    json_data = json.dumps(page_df_clean.to_dict(orient="records"))
    print("Conversion JSON réussie !")
    print(json_data)
except Exception as e:
    print("Erreur lors de la conversion JSON :", e)
# Out:
#   TRANSACTION_ID                    TIMESTAMP  \
# 0   TXN-4aeb6c15  2025-04-19T07:20:12.305600Z
# 1   TXN-cdf1eb54  2025-04-17T08:57:51.305600Z
# 2   TXN-05db4e32  2025-04-14T00:25:23.305600Z
# 3   TXN-3b1bb2d2  2025-05-08T11:38:25.312495Z
# 4   TXN-c9f2d7da  2025-04-27T03:14:24.305600Z
# 5   TXN-8e7c7031  2025-04-26T08:05:23.312495Z
# 6   TXN-50d21d0c  2025-05-07T14:13:09.312495Z
# 7   TXN-492b36c3  2025-04-24T10:00:22.312495Z
# 8   TXN-c61925f2  2025-04-25T06:41:30.305600Z
#
#                      USER_ID_HASHED                  USER_NAME_HASHED  \
# 0  54f57e09864b54ed59a5cc633673dde4  194cd2f711cebc782ada13e259bf61dd
# 1  3ff77438146870ee5dcd120f13dec323  01c3012a4b4c3a3ed2aeefefafa38cc5
# 2  385f7d23d00928a441e647da673b2c06  88700f697fe98f2bf0370a7114d5bacf
# 3  7271fbbbc55316d6aab210f25eeda95c  5447aa4026288039fccf95cf270282b3
# 4  2b4f14972a7ae2a887a3bdaade7bf126  262031397020fd8df478ec13b4b096c5
# 5  71deaaea048fc460df652343efe92b98  72626c2e45e149d005a0d408e80dcfea
# 6  0cf6d14a6247e5ed79930b0d9bf65651  93ea6597c3cbd06e93a46b9f5368732d
# 7  526a367d768fdced0719b275252eb7b4  96db69b0fff794de363fbb73929ac604
# 8  2efb7d3fc84a4e198fea300197350bcb  61409aa1fd47d4a5332de23cbf59a36f
#
#   PRODUCT_ID  AMOUNT CURRENCY TRANSACTION_TYPE   STATUS            CITY  ...  \
# 0   PROD-669  873.04      JPY          payment  pending        Salvador  ...
# 1   PROD-506  416.12      EUR           refund  pending       São Paulo  ...
# 2   PROD-933  469.41      CAD           refund  pending       Frankfurt  ...
# 3   PROD-609  776.81      GBP          payment  pending         Houston  ...
# 4   PROD-711  970.32      GBP       withdrawal  pending  Rio de Janeiro  ...
# 5   PROD-832  710.38      JPY          payment  pending         Chennai  ...
# 6   PROD-409  796.47      GBP       withdrawal  pending        Brisbane  ...
# 7   PROD-970  719.11      AUD           refund  pending         Beijing  ...
# 8   PROD-359  281.52      CAD           refund  pending          Mumbai  ...
#
#          MASKED_IP CUSTOMER_RATING DISCOUNT_CODE TAX_AMOUNT THREAD  \
# 0  67.112.9xxx.xxx            None          None        0.0      2
# 1  102.103.xxx.xxx            None          None        0.0      1
# 2  130.68.4xxx.xxx            None          None        0.0      2
# 3  239.133.xxx.xxx            None          None        0.0      3
# 4  94.167.1xxx.xxx            None  DISCOUNT-327        0.0      2
# 5  253.19.2xxx.xxx             3.0          None        0.0      4
# 6  85.130.1xxx.xxx            None  DISCOUNT-406        0.0      4
# 7  2.154.10xxx.xxx            None  DISCOUNT-742        0.0      3
# 8  121.211.xxx.xxx            None  DISCOUNT-341        0.0      0
#
#   MESSAGE_NUMBER TIMESTAMP_OF_RECEPTION_LOG AMOUNT_USD  \
# 0              0        11/05/2025 12:32:55    6.11128
# 1              1        11/05/2025 12:32:55   449.4096
# 2              2        11/05/2025 12:32:55   352.0575
# 3              3        11/05/2025 12:32:55   963.2444
# 4              3        11/05/2025 12:32:55  1203.1968
# 5              5        11/05/2025 12:32:55    4.97266
# 6              6        11/05/2025 12:32:55   987.6228
# 7              8        11/05/2025 12:32:55   474.6126
# 8              9        11/05/2025 12:32:55     211.14
#
#             ingestion_time ingestion_date
# 0  2025-05-11 12:45:35.844     2025-05-11
# 1  2025-05-11 12:45:35.844     2025-05-11
# 2  2025-05-11 12:45:35.844     2025-05-11
# 3  2025-05-11 12:45:35.844     2025-05-11
# 4  2025-05-11 12:45:35.844     2025-05-11
# 5  2025-05-11 12:45:35.844     2025-05-11
# 6  2025-05-11 12:45:35.844     2025-05-11
# 7  2025-05-11 12:45:35.844     2025-05-11
# 8  2025-05-11 12:45:35.844     2025-05-11
#
# [9 rows x 30 columns]
# Conversion JSON réussie !
# [{"TRANSACTION_ID": "TXN-4aeb6c15", "TIMESTAMP": "2025-04-19T07:20:12.305600Z", "USER_ID_HASHED": "54f57e09864b54ed59a5cc633673dde4", "USER_NAME_HASHED": "194cd2f711cebc782ada13e259bf61dd", "PRODUCT_ID": "PROD-669", "AMOUNT": 873.04, "CURRENCY": "JPY", "TRANSACTION_TYPE": "payment", "STATUS": "pending", "CITY": "Salvador", "COUNTRY": "Brazil", "PAYMENT_METHOD": "paypal", "PRODUCT_CATEGORY": "food", "QUANTITY": 9, "SHIPPING_STREET": "980 Main St", "SHIPPING_ZIP": "80949", "SHIPPING_CITY": "Salvador", "SHIPPING_COUNTRY": "Brazil", "DEVICE_OS": "Linux", "DEVICE_BROWSER": "Safari", "MASKED_IP": "67.112.9xxx.xxx", "CUSTOMER_RATING": null, "DISCOUNT_CODE": null, "TAX_AMOUNT": 0.0, "THREAD": 2, "MESSAGE_NUMBER": 0, "TIMESTAMP_OF_RECEPTION_LOG": "11/05/2025 12:32:55", "AMOUNT_USD": 6.11128, "ingestion_time": "2025-05-11 12:45:35.844", "ingestion_date": "2025-05-11"}, {"TRANSACTION_ID": "TXN-cdf1eb54", "TIMESTAMP": "2025-04-17T08:57:51.305600Z", "USER_ID_HASHED": "3ff77438146870ee5dcd120f13dec323", "USER_NAME_HASHED": "01c3012a4b4c3a3ed2aeefefafa38cc5", "PRODUCT_ID": "PROD-506", "AMOUNT": 416.12, "CURRENCY": "EUR", "TRANSACTION_TYPE": "refund", "STATUS": "pending", "CITY": "S\u00e3o Paulo", "COUNTRY": "Brazil", "PAYMENT_METHOD": "credit_card", "PRODUCT_CATEGORY": "food", "QUANTITY": 9, "SHIPPING_STREET": "723 Main St", "SHIPPING_ZIP": "66963", "SHIPPING_CITY": "S\u00e3o Paulo", "SHIPPING_COUNTRY": "Brazil", "DEVICE_OS": "MacOS", "DEVICE_BROWSER": "Firefox", "MASKED_IP": "102.103.xxx.xxx", "CUSTOMER_RATING": null, "DISCOUNT_CODE": null, "TAX_AMOUNT": 0.0, "THREAD": 1, "MESSAGE_NUMBER": 1, "TIMESTAMP_OF_RECEPTION_LOG": "11/05/2025 12:32:55", "AMOUNT_USD": 449.4096, "ingestion_time": "2025-05-11 12:45:35.844", "ingestion_date": "2025-05-11"}, {"TRANSACTION_ID": "TXN-05db4e32", "TIMESTAMP": "2025-04-14T00:25:23.305600Z", "USER_ID_HASHED": "385f7d23d00928a441e647da673b2c06", "USER_NAME_HASHED": "88700f697fe98f2bf0370a7114d5bacf", "PRODUCT_ID": "PROD-933", "AMOUNT": 469.41, "CURRENCY": "CAD", "TRANSACTION_TYPE": "refund", "STATUS": "pending", "CITY": "Frankfurt", "COUNTRY": "Germany", "PAYMENT_METHOD": "bank_transfer", "PRODUCT_CATEGORY": "clothing", "QUANTITY": 8, "SHIPPING_STREET": "109 Main St", "SHIPPING_ZIP": "41157", "SHIPPING_CITY": "Frankfurt", "SHIPPING_COUNTRY": "Germany", "DEVICE_OS": "iOS", "DEVICE_BROWSER": "Firefox", "MASKED_IP": "130.68.4xxx.xxx", "CUSTOMER_RATING": null, "DISCOUNT_CODE": null, "TAX_AMOUNT": 0.0, "THREAD": 2, "MESSAGE_NUMBER": 2, "TIMESTAMP_OF_RECEPTION_LOG": "11/05/2025 12:32:55", "AMOUNT_USD": 352.0575, "ingestion_time": "2025-05-11 12:45:35.844", "ingestion_date": "2025-05-11"}, {"TRANSACTION_ID": "TXN-3b1bb2d2", "TIMESTAMP": "2025-05-08T11:38:25.312495Z", "USER_ID_HASHED": "7271fbbbc55316d6aab210f25eeda95c", "USER_NAME_HASHED": "5447aa4026288039fccf95cf270282b3", "PRODUCT_ID": "PROD-609", "AMOUNT": 776.81, "CURRENCY": "GBP", "TRANSACTION_TYPE": "payment", "STATUS": "pending", "CITY": "Houston", "COUNTRY": "USA", "PAYMENT_METHOD": "cryptocurrency", "PRODUCT_CATEGORY": "food", "QUANTITY": 3, "SHIPPING_STREET": "619 Main St", "SHIPPING_ZIP": "47540", "SHIPPING_CITY": "Houston", "SHIPPING_COUNTRY": "USA", "DEVICE_OS": "Linux", "DEVICE_BROWSER": "Safari", "MASKED_IP": "239.133.xxx.xxx", "CUSTOMER_RATING": null, "DISCOUNT_CODE": null, "TAX_AMOUNT": 0.0, "THREAD": 3, "MESSAGE_NUMBER": 3, "TIMESTAMP_OF_RECEPTION_LOG": "11/05/2025 12:32:55", "AMOUNT_USD": 963.2443999999999, "ingestion_time": "2025-05-11 12:45:35.844", "ingestion_date": "2025-05-11"}, {"TRANSACTION_ID": "TXN-c9f2d7da", "TIMESTAMP": "2025-04-27T03:14:24.305600Z", "USER_ID_HASHED": "2b4f14972a7ae2a887a3bdaade7bf126", "USER_NAME_HASHED": "262031397020fd8df478ec13b4b096c5", "PRODUCT_ID": "PROD-711", "AMOUNT": 970.32, "CURRENCY": "GBP", "TRANSACTION_TYPE": "withdrawal", "STATUS": "pending", "CITY": "Rio de Janeiro", "COUNTRY": "Brazil", "PAYMENT_METHOD": "credit_card", "PRODUCT_CATEGORY": "electronics", "QUANTITY": 9, "SHIPPING_STREET": "948 Main St", "S ...
